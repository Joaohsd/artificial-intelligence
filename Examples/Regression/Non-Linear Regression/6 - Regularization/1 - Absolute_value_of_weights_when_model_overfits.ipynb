# %%
# Import all the necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
# Reset pseudo random number generator so that the results are reproducible.
np.random.seed(42)

# %% [markdown]
# ### Generating the target function and its noisy version.

# %%
# Sets the number of examples.
N = 20

# Attribute.
x = np.sort(3*np.random.rand(N, 1), axis=0)

# Target function.
y = 1 + 0.5*x

# Noise.
w = np.random.randn(N, 1)

# Observable function (noisy).
y_noisy = y + w

# %%
# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
#plt.savefig("target_function.png", dpi=600)
#Show the plot.
plt.show()

# %% [markdown]
# ### Poynomial order 1

# %%
# Polynomial order.
model_order = 1

# %%
# Concatenate both column vectors.
X = np.ones((N,1))
for i in range(1, model_order+1):
    X = np.c_[X, np.power(x, i)]

# Instantiate standard scaler. 
scaler = StandardScaler()

# Create the attribute matrix and standardize the samples.
X = np.c_[np.ones((N,1)), scaler.fit_transform(X[:,1:])]

# Instantiate.
reg1 = LinearRegression(fit_intercept=False)

# Train.
reg1.fit(X, y_noisy)

# Predict.
ypred = reg1.predict(X)

# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x, ypred, label='Hipótese')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
plt.axis([0, 3, 0, 4])
#Show the plot.
plt.show()

# %% [markdown]
# ### Poynomial order 5

# %%
# Polynomial order.
model_order = 5

# %%
# Concatenate both column vectors.
X = np.ones((N,1))
for i in range(1, model_order+1):
    X = np.c_[X, np.power(x, i)]

# Instantiate standard scaler. 
scaler = StandardScaler()

# Create the attribute matrix and standardize the samples.
X = np.c_[np.ones((N,1)), scaler.fit_transform(X[:,1:])]

# Instantiate.
reg5 = LinearRegression(fit_intercept=False)

# Train.
reg5.fit(X, y_noisy)

# Predict.
ypred = reg5.predict(X)

# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x, ypred, label='Hipótese')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
plt.axis([0, 3, 0, 4])
#Show the plot.
plt.show()

# %% [markdown]
# ### Poynomial order 10

# %%
# Polynomial order.
model_order = 10

# %%
# Concatenate both column vectors.
X = np.ones((N,1))
for i in range(1, model_order+1):
    X = np.c_[X, np.power(x, i)]

# Instantiate standard scaler. 
scaler = StandardScaler()

# Train and standardize samples.
X = np.c_[np.ones((N,1)), scaler.fit_transform(X[:,1:])]

reg10 = LinearRegression(fit_intercept=False)

reg10.fit(X, y_noisy)

ypred = reg10.predict(X)

# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x, ypred, label='Hipótese')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
plt.axis([0, 3, 0, 4])
#Show the plot.
plt.show()

# %% [markdown]
# ### Poynomial order 20

# %%
# Polynomial order.
model_order = 20

# %%
# Concatenate both column vectors.
X = np.ones((N,1))
for i in range(1, model_order+1):
    X = np.c_[X, np.power(x, i)]

# Instantiate standard scaler. 
scaler = StandardScaler()

# Train and standardize samples.
X = np.c_[np.ones((N,1)), scaler.fit_transform(X[:,1:])]

reg20 = LinearRegression(fit_intercept=False)

reg20.fit(X, y_noisy)

ypred = reg20.predict(X)

# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x, ypred, label='Hipótese')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
plt.axis([0, 3, 0, 4])
#Show the plot.
plt.show()

# %% [markdown]
# ### Wheights for polynomial order 1

# %%
print(reg1.coef_)
# Out:
# [[1.41373931 0.54963632]]

# %% [markdown]
# ### Wheights for polynomial order 5

# %%
print(reg5.coef_)
# Out:
# [[  1.41373931   6.63487126 -42.70669286 101.69748722 -99.54813452
#    34.41082453]]

# %% [markdown]
# ### Wheights for polynomial order 10

# %%
print(reg10.coef_)
# Out:
# [[ 1.41373931e+00  1.80163868e+02 -4.33810514e+03  4.45166386e+04
#   -2.48521724e+05  8.32599976e+05 -1.74696276e+06  2.31229143e+06
#   -1.87427547e+06  8.49175076e+05 -1.64664226e+05]]

# %% [markdown]
# ### Wheights for polynomial order 20

# %%
print(reg20.coef_)
# Out:
# [[ 1.40790944e+00  3.59638407e+06 -1.44048896e+08  2.82794252e+09
#   -3.43052333e+10  2.82196368e+11 -1.65161612e+12  7.05536606e+12
#   -2.22082707e+13  5.11473500e+13 -8.33465268e+13  8.67771224e+13
#   -3.50715466e+13 -4.36041771e+13  7.35018973e+13 -2.05714738e+13
#   -5.55941461e+13  7.93754963e+13 -5.03241076e+13  1.65687285e+13
#   -2.30467436e+12]]

# %% [markdown]
# ### Conclusion
#
# + Increased model flexibility resulted in increased magnitude of weights
#
# + What regularization does is constrain the magnitudes and consequently minimize the error function.
